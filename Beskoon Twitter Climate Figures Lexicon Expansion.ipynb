# %% [markdown]
# # Twitter Followers by Climate Figures Lexicon Expansion
# Logan Beskoon

# %%
import pandas as pd
import html
import re
from re import search
import html
import emoji
import random
import numpy as np
import nltk
from nltk.corpus import stopwords
from operator import itemgetter
from itertools import islice

from collections import Counter

sw = stopwords.words('english', 'spanish')

# %% [markdown]
# For this notebook, we will be taking Twitter descriptions from the accounts CFiguerers' and EcoSenseNow's. They are in an interesting climate space, one calling for climate action now and the other trying to make sense of climate discussion positioning against fear. I will be running a lexicon expansion, specifically creating a subgroup for each follower group that is initialized by education. Then I will do a final group comparison of those two subgroups based on there lexicon that I created.
#
# This data was sourced from Twitter. I pulled the Twitter followers of two fairly well-known individuals in regard to climate action views. The account CFiguerers is I Christiana Figueres. She is an internationally recognized leader on climate change and typically calls for strong action. The second account, EcoSenseNow, belongs to Patrick Moore. He considers himself a sensible environmentalist. He is strongly against taking drastic action in the name of climate change. And he is also the director of C02Coalition (https://co2coalition.org/) which advocates “ to engage in an informed and dispassionate discussion of climate change, humans’ role in the climate system, the limitations of climate models, and the consequences of mandated reductions in CO2 emissions”. Looking at the users’ descriptions that follow each figure, I would hypothesis that we could create an interesting comparing in word usage.
#
# First, there are just a few functions we are going to call. The important one is quick_compare which will build out our lexicon for our subgroups. Group_compare will be called for our final group comparison.

# %%
def get_patterns(text, num_words)  :
        """
        This function takes text as an input and returns a dictionary of statistics,
        after cleaning the text. 
    
        """
    
    
        # Calculate your statistics here
        total_tokens = len(text)
        unique_tokens = len(set(text))
        #token length vector
        text_token_len = [len(w) for w in text]
        avg_token_len = (np.mean(text_token_len))
        lex_diversity = (len(set(text))/len(text))
        top_10 = Counter(text).most_common(num_words)
    


    
    
        # Now we'll fill out the dictionary. 
        stats = {'tokens':total_tokens,
               'unique_tokens':unique_tokens,
               'avg_token_length':avg_token_len,
               'lexical_diversity':lex_diversity,
               'top_10':top_10}
        
        return(stats)

# %%
def concentration(text, ratio_cutoff):
    """
    This function gets the concentrations for all words in a text.
    """
    con = {}
    fd = nltk.FreqDist(text)
    for word, count in fd.items():
        if count > ratio_cutoff:
            con_word = fd.freq(word)
            con.update({word: con_word})
        else:
            continue
    return(con)

# %%
def relative_ratios(con_dict1, con_dict2):
    """
    This function creates our relative ratios based on two incoming concentration ratio dicts,
    """
    
    ratiocon = {}
    for word, con in con_dict1.items():
        if word in con_dict2.keys():
            ratio =(con_dict1[word])/(con_dict2[word])
            ratiocon.update({word:ratio})
        else: 
            continue
    return(ratiocon)

# %%
def quick_compare(text1, text2, num_words=10, ratio_cutoff=5):
    """
    This function takes two corpora, and outputs a nested dictionary without text stats.
    
    """
    
    # our master nested dictionary
    results = {}
   
    
    # Now let's get our concentrations
    text1_con = concentration(text1, ratio_cutoff)
    text2_con = concentration(text2, ratio_cutoff)
    
    
    # Now we can get the top num_words relative frequencies. 
    text1_ratios = relative_ratios(text1_con, text2_con)
    text2_ratios = relative_ratios(text2_con, text1_con)
            
    #Text 1 relative ratio        
    sorted_dict1 = {}
    for word, ratio in sorted(text1_ratios.items(), key=lambda x: x[1], reverse=True):
        sorted_dict1[word] = ratio
    text1_final = dict(islice(sorted_dict1.items(), num_words)) 
    
    #Text 2 relative ratio
    sorted_dict2 = {}
    for word, ratio in sorted(text2_ratios.items(), key=lambda x: x[1], reverse=True):
        sorted_dict2[word] = ratio
    text2_final = dict(islice(sorted_dict2.items(), num_words))
    
    #add these ratios to our results dict
    results.update({"One_vs_two":text1_final , "Two_vs_one": text2_final})
    
    
    
    return(results)

# %%
def group_compare(text1, text2, num_words=10, ratio_cutoff=5):
    """
    This function takes two corpora, and outputs a nested dictionary.
    
    """
    
    # our master nested dictionary
    results = {}



    #apply stats function, put into results
    text1_stats = get_patterns(text1, num_words)
    text2_stats = get_patterns(text2, num_words)
    
    results = {"One": text1_stats, "Two": text2_stats}
   
    
    
    # Now let's get our concentrations
    text1_con = concentration(text1, ratio_cutoff)
    text2_con = concentration(text2, ratio_cutoff)
    
    
    # Now we can get the top num_words relative frequencies. 
    text1_ratios = relative_ratios(text1_con, text2_con)
    text2_ratios = relative_ratios(text2_con, text1_con)
            
    #Text 1 relative ratio        
    sorted_dict1 = {}
    for word, ratio in sorted(text1_ratios.items(), key=lambda x: x[1], reverse=True):
        sorted_dict1[word] = ratio
    text1_final = dict(islice(sorted_dict1.items(), num_words)) 
    
    #Text 2 relative ratio
    sorted_dict2 = {}
    for word, ratio in sorted(text2_ratios.items(), key=lambda x: x[1], reverse=True):
        sorted_dict2[word] = ratio
    text2_final = dict(islice(sorted_dict2.items(), num_words ))
    
    #add these ratios to our results dict
    results.update({"One_vs_two":text1_final , "Two_vs_one": text2_final})
    
    
    
    return(results)

# %% [markdown]
# ## First Group
#
# We will start with CFiguerers' followers. Let's read it in, select only the description and clean it up.

# %%
pd.set_option('display.max_colwidth', None)

CF = pd.read_csv('CFigueres_followers.txt', encoding='utf8', header = 0, sep='\t', lineterminator='\r',
                   dtype={"screen_name": str,
                          "user_id": str,
                          "name": str,
                          "location": str,
                          "followers_count": str,
                          "friends_count": str,
                          "description": str})


CF_followers = CF.dropna(axis = 0, subset=['description'])
CF_followers
# Out:
#              screen_name                  name            ID  \
# 0          \nryangzepeda           Ryan Zepeda  8.113401e+17
# 1       \nStefanoutdoors         Stefan Zeeman  1.326808e+18
# 3             \nkosickey        Karen O'Sickey  1.033585e+08
# 5           \nJackie_OPR        Jackie Simpson  1.048317e+18
# 6        \nClara_Mottura                 Clara  1.457754e+18
# ...                  ...                   ...           ...
# 158734        \ndavilalu           Luis Dávila  9.351621e+07
# 158735        \nNaimavRF  Naima v Ritter Figue  2.480277e+08
# 158736     \nmedinagomez          Sonia Medina  2.729387e+07
# 158737  \nAfriRenBiomass        AfriRenBiomass  2.265923e+08
# 158738          \nUNFCCC     UN Climate Change  1.746392e+07
#
#                         Location  Followers_Count  Friends_Count  \
# 0                            NaN            145.0          702.0
# 1                            NaN             20.0           99.0
# 3           Hiram Township, Ohio             42.0           98.0
# 5       Scotland, United Kingdom            137.0          553.0
# 6                            NaN              1.0           65.0
# ...                          ...              ...            ...
# 158734               Seattle, WA           2148.0         1845.0
# 158735                       NaN            397.0          199.0
# 158736                    London           1867.0         1200.0
# 158737    London, Accra, Abidjan            380.0          198.0
# 158738             Bonn, Germany         859922.0         1050.0
#
#                                                                                                                                                         description
# 0                                                                                                                                   Houston, Texas | Texas A&M Alum
# 1                                                                                                                  All things wild and environmental, @carbonrewild
# 3                                                                          change agent, life-long learner; health nut; love the outdoors, technology, and the arts
# 5                             Founder @outletplayre | Play Enabler | Hitter of drums in @sambayabamba  | Home stuff & work stuff 🏴󠁧󠁢󠁳󠁣󠁴󠁿 | Views my own |   She/Her
# 6                                                                                                                               Conscious Sustainability Enthusiast
# ...                                                                                                                                                             ...
# 158734                                     Leading sustainability communications @Amazon. ex @Sunrun ex @UNFCCC. All tweets are my personal views. RT≠ endorsement.
# 158735                                                           Transformational Coach and Space Facilitator. Head of Community & Wellbeing for Conscious Coliving
# 158736                          Executive Director Climate Change at @CIFFchild. WEF Young Global Leader. Mother. Internationalist. Views my own. RTs not endorsem.
# 158737                 AfriRen provides European industry with stable, long term supplies of quality biomass. Follow us for all the latest news on Renewable Energy
# 158738  Official twitter account of UN Climate Change. Also in Spanish @CMNUCC, French @CCNUCC, Russian @RKIKOON and German @UNKlima. Our head: @PEspinosaC. #COP26
#
# [117279 rows x 7 columns]

# %%
# Convert to correct data types
CF_followers = CF_followers.convert_dtypes(infer_objects=True, convert_string=True, convert_integer=True, convert_boolean=True, convert_floating=True
    
#CF_followers.dtypes
# Out:
#   File "C:\Users\logan\AppData\Local\Temp/ipykernel_23196/2602450162.py", line 4
#     #CF_followers.dtypes
#                         ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# Now we need to clean the Tweets up some. This includes tokenization and normalization. We can also see that there are emojis in the tweets, and for this analysis we want to remove those as well.

# %%
CF_descs = CF_followers['description']
CF_clean_descs = []
for desc in CF_descs:
    temp = desc.lower()
    temp = re.sub("@[A-Za-z0-9_]+", "", temp)
    temp = re.sub("#[A-Za-z0-9_]+", "", temp)
    temp = re.sub(r"http\S+", "", temp)
    temp = re.sub(r"www.\S+", "", temp)
    temp = re.sub('[()|!?]', ' ', temp)
    temp = re.sub('\[.*?\]', ' ', temp)
    temp = re.sub("[^a-z0-9]", " ", temp)
    temp = re.sub(r"[0-9]", " ", temp)
    temp = temp.split()
    temp =[w for w in temp if not w in sw]
    temp = " ".join(word for word in temp)
    CF_clean_descs.append(temp)
    
    
print(CF_clean_descs[:10])
# Out:
# ['houston texas texas alum', 'things wild environmental', 'change agent life long learner health nut love outdoors technology arts', 'founder play enabler hitter drums home stuff work stuff views', 'conscious sustainability enthusiast', 'passionate places live love dish one spoon year banking career previous fishing lodge owner serving wainfleet councilor', 'roaming entrepreneur', 'need followers listen agree disagree think global friend female made brum oh european absolutely european marched', 'veces veces vengo llegando de un viaje en el tiempo soy parte de team pero digan nada', 'geographer urban ecologist w risa program fellow ej climate justice spatial politics climate adaptation floodplain mgmt']

# %% [markdown]
# Our Tweets look pretty clean now. Let's insert them back into our dataframe in a new column called Clean.

# %%
CF_descs = CF_descs.to_frame()
CF_descs['Clean'] = CF_clean_descs
CF_descs.head()
# Out:
#                                                                                                                              description  \
# 0                                                                                                        Houston, Texas | Texas A&M Alum
# 1                                                                                       All things wild and environmental, @carbonrewild
# 3                                               change agent, life-long learner; health nut; love the outdoors, technology, and the arts
# 5  Founder @outletplayre | Play Enabler | Hitter of drums in @sambayabamba  | Home stuff & work stuff 🏴󠁧󠁢󠁳󠁣󠁴󠁿 | Views my own |   She/Her
# 6                                                                                                    Conscious Sustainability Enthusiast
#
#                                                                      Clean
# 0                                                 houston texas texas alum
# 1                                                things wild environmental
# 3  change agent life long learner health nut love outdoors technology arts
# 5            founder play enabler hitter drums home stuff work stuff views
# 6                                      conscious sustainability enthusiast

# %% [markdown]
# ### Lexicon GO
# First we want to pull out a random word from the tweets. To do this, we will pull 50 random tweets and choose a word that seems to define some sub group hypothetically. Remember, we are looking of education focused words.

# %%
CF_descs.sample(50)
# Out:
#                                                                                                                                                              description  \
# 58760                                                                                                     Soy una persona humilde y devertido   Me gustan los ANIMALES😚😚
# 33006                                                                       “The future belongs to those who believe in the beauty of their dreams.” — Eleanor Roosevelt
# 2212         #blacklivesmatter, 🏳️‍🌈, walkable/transit-abundant cities, housing justice + historic preservation, Vermont native,  he/him/his. World peace through music.
# 22092                                                                                                                                     Traveler  moto tour  adventure
# 27197                                                                                                          Learner , Nature love , Dreamer , Meditation., Heritage -
# 22817                We fund the best projects to help offset carbon impact. Want to make a difference? Join us in our mission to stop and reverse climate change today.
# 59801                                                             Supporting campaigners around the UK with Friends of the Earth. Occasional barman. Opinions are my own
# 53114          GWNET aims to advance the global energy transitions by empowering women in energy through interdisciplinary networking, advocacy, training and mentoring.
# 84826                 American Wop about people who suffer the destruction of beautiful America. #Author #Environment #green  #fish #carpenter #NYC #Sail #Navy #ET #MBA
# 31030                                                                                                                                                ING eléctrica /CR🇨🇷
# 28449                                                 artist and project coordinator @juiceboxfm / dj and promoter @palasounds / monthly show on https://t.co/h1PUK5wcpY
# 71575                                                                                                                                                    pns pemprov bkl
# 86416         وزير الصناعة والتجارة 🇲🇦 المملكة المغربية  Ministre de l'Industrie et du Commerce 🇲🇦 Royaume du Maroc  Minister of Industry and Trade 🇲🇦Kingdom of Morocco
# 137587                  Supporting cooperation and collaboration among Bainbridge Island orgs., biz, gov't and individuals to strengthen our community's sustainability.
# 23215                                                               Visual storyteller. Part-time jungle cat. See https://t.co/g9yk4R2cTV for images. Based in #Colombo.
# 139805                                                                                                                Before doing anything one should think repeatedly.
# 116137                                La @banquedesterr finance, conseille & opère auprès de tous les territoires Français pour l’intérêt général ! #AFondLesTerritoires
# 119875                                            La Política Nacional del Océano y los Espacios Costeros (PNOEC) busca convertir al país en una potencia media oceánica
# 98351                Communications Director at World Shipping Council. All about liner shipping, responsible logistics and the Blue Ocean economy. Opinions are my own.
# 45869                             50 years old, was in the navy for 22 year. now I have a small business steeve craft house. selling walking stick bellrop and necklace.
# 35649                 husband. father of two. engineer. Master of Natural Resources in sustainability and resiliency. passionate about the environment. Wisconsin native
# 109911  Energy journalist. Co-host, Columbia Energy Exchange podcast. Dir., Columbia Energy Journalism Initiative. Anchored Platts Energy Week TV. Retweets≠endorsements
# 105947          To inspire a generation of new voices to “speak up and speak out”, empowering adolescent girls and young women to achieve their real and full potential.
# 154713                                                      We're Climate Change Connection. A hub for information about climate change facts and solutions in Manitoba.
# 30929                                                         Africa’s optimist in chief Positive Change Maker Thought Leader Father/Son/Friend/ Brother/BIPOCFOUNDATION
# 101337                                      MBA Management & Energy | @sagemcom | @IONISSTM | EnerNerd | Business | Innovation | Traveller | Dreamer | @realmadrid fan |
# 60330                                     🇮🇹🇪🇺 | Erasmus 2015 @UPOlomouc 🇨🇿 | @LaStatale & @unito alumnus 🇮🇹 | EU&ITA Affairs here | Progressive liberal, personal views
# 56049     Research scientist @FishOceansCAN. Physical-biogeochemical interactions & ocean climate in NL. Like #science #bike #openSource & #freeKnowledge. Views my own.
# 88812                                                                                                                                           Cyclist and Data Manager
# 153540                            Board member and senior expert in ESG and sustainable investing - for #integrated financial and social outcomes. All views are my own.
# 129560                                                                                                    Passionate Fine Artist. Child of God. Proud African & a Gooner
# 111971                                                                                        i m a man of many talents. i am a gay man and proud of it. i am 28 yr old.
# 18758                                                                                     Solutions are in nature... for a just and sustainable future... (views my own)
# 53110                                  🚉 • B.Eng. Geographer and Environmental | Urban & Regional Planning & Sustainable transport 🚲, Cartography • Researcher  🏙🌎| 🇨🇴 |
# 134450      LetzKeepItREAL Family Of Networks Is NOW OPEN! Visit Us Worldwide! See Whats HoT In Technology, Communicate, Collaborate, Share Interests & Ideas Worldwide!
# 8775                                                                                                                                            Ad Majorem Dei Gloriam 💎
# 54536                              Journaliste Santé-Environnement Sec.dirigeante du CI ORTF @Francetele @francetv @AssoJNE @SnjCgt @CiortfCi #aspie RT not endorsements
# 80551                           Norwegian women-owned business. We make fresh omega-3 from Arctic cod caught by Norwegian fishermen. Mermaids Omega-3 / Havfruenes tran.
# 34645                                                                                                                       MCVP BD / National Corporate at AIESECinTogo
# 91359           Je me préoccupe principalement d'agriculture et d'agronomie.   Expérience terrain en financement et en gestion agricole.  Fier d'être agronome au Québec
# 23129                                                                 (she/her) | 🇨🇦Canadian Red Cross | An advocate of Human Rights, Gender Equality and Sustainability
# 94694               International Development Practitioner. formerly @UNDPNigeria 🇳🇬 Social Protection Associate @ifad fellow. Passionate about #SDGs, @MDPGlobal alumni
# 133616                                                                                                                                                   Content Creator
# 38275                               ι aм alιve and мayвe ι'м noт. ✮⁎✧⁎✧⁎✮  🏴󠁧󠁢󠁳󠁣󠁴󠁿ѕcoт 🇪🇺🇪🇺eυropean 🌍🌍🌍earтнer     😷  ✦ . ✦   нard green & ѕocιalιѕт ➿🏳️‍🌈ࢪ Anti-fascist
# 43250          Eterno buscador de lo aún no encontrado! Busco todo lo que quiero y quiero todo lo que deseo! Así ando por el mundo...en busca de algo nuevo que me rete.
# 95903                                                                                           practicant alternatives ecofeministes des de ciutat / hort urbà caladona
# 67800                                                                          Articles association re election report contd ..and who have held room during the period.
# 115645                                                                                   Jungler Platine EUW , utilisation de l'épouvantail pour passer diamant en cours
# 47297    From Lancaster University: a Royal Society Summer Science Exhibition 2019 exploring noise and isolation in physics. Enquiries to @benrobinson or @samjarvisnano
# 26479                 PhD | Human geographer focused on energy transitions | Director- @team_empower and @zuwaenergy | Thinking about off-grid solar repair and e-waste.
#
#                                                                                                                                                             Clean
# 58760                                                                                                       soy una persona humilde devertido gustan los animales
# 33006                                                                                                      future belongs believe beauty dreams eleanor roosevelt
# 2212                                                      walkable transit abundant cities housing justice historic preservation vermont native world peace music
# 22092                                                                                                                                traveler moto tour adventure
# 27197                                                                                                             learner nature love dreamer meditation heritage
# 22817                                         fund best projects help offset carbon impact want make difference join us mission stop reverse climate change today
# 59801                                                                                   supporting campaigners around uk friends earth occasional barman opinions
# 53114                               gwnet aims advance global energy transitions empowering women energy interdisciplinary networking advocacy training mentoring
# 84826                                                                                                    american wop people suffer destruction beautiful america
# 31030                                                                                                                                            ing el ctrica cr
# 28449                                                                                                         artist project coordinator dj promoter monthly show
# 71575                                                                                                                                             pns pemprov bkl
# 86416                                                             ministre de l industrie et du commerce royaume du maroc minister industry trade kingdom morocco
# 137587                                  supporting cooperation collaboration among bainbridge island orgs biz gov individuals strengthen community sustainability
# 23215                                                                                                    visual storyteller part time jungle cat see images based
# 139805                                                                                                                              anything one think repeatedly
# 116137                                                                         la finance conseille op aupr de tous les territoires fran ais pour l int r g n ral
# 119875                                           la pol tica nacional del oc ano los espacios costeros pnoec busca convertir al pa en una potencia media oce nica
# 98351                                             communications director world shipping council liner shipping responsible logistics blue ocean economy opinions
# 45869                                                                years old navy year small business steeve craft house selling walking stick bellrop necklace
# 35649                                      husband father two engineer master natural resources sustainability resiliency passionate environment wisconsin native
# 109911  energy journalist co host columbia energy exchange podcast dir columbia energy journalism initiative anchored platts energy week tv retweets endorsements
# 105947                                              inspire generation new voices speak speak empowering adolescent girls young women achieve real full potential
# 154713                                                                          climate change connection hub information climate change facts solutions manitoba
# 30929                                                        africa optimist chief positive change maker thought leader father son friend brother bipocfoundation
# 101337                                                                                   mba management energy enernerd business innovation traveller dreamer fan
# 60330                                                                                           erasmus alumnus eu ita affairs progressive liberal personal views
# 56049                                                                         research scientist physical biogeochemical interactions ocean climate nl like views
# 88812                                                                                                                                        cyclist data manager
# 153540                                                                       board member senior expert esg sustainable investing financial social outcomes views
# 129560                                                                                                      passionate fine artist child god proud african gooner
# 111971                                                                                                                      man many talents gay man proud yr old
# 18758                                                                                                                   solutions nature sustainable future views
# 53110                                                         b eng geographer environmental urban regional planning sustainable transport cartography researcher
# 134450                    letzkeepitreal family networks open visit us worldwide see whats hot technology communicate collaborate share interests ideas worldwide
# 8775                                                                                                                                       ad majorem dei gloriam
# 54536                                                                                    journaliste sant environnement sec dirigeante du ci ortf rt endorsements
# 80551                                        norwegian women owned business make fresh omega arctic cod caught norwegian fishermen mermaids omega havfruenes tran
# 34645                                                                                                                     mcvp bd national corporate aiesecintogo
# 91359                   je pr occupe principalement agriculture et agronomie exp rience terrain en financement et en gestion agricole fier tre agronome au qu bec
# 23129                                                                                     canadian red cross advocate human rights gender equality sustainability
# 94694                                                        international development practitioner formerly social protection associate fellow passionate alumni
# 133616                                                                                                                                            content creator
# 38275                                                                                                     al ay e co e ropean ear er ard green oc al anti fascist
# 43250                      eterno buscador de lo n encontrado busco todo lo que quiero quiero todo lo que deseo ando por el mundo en busca de algo nuevo que rete
# 95903                                                                                       practicant alternatives ecofeministes des de ciutat hort urb caladona
# 67800                                                                                                 articles association election report contd held room period
# 115645                                                                               jungler platine euw utilisation de l pouvantail pour passer diamant en cours
# 47297                                                    lancaster university royal society summer science exhibition exploring noise isolation physics enquiries
# 26479                                                                 phd human geographer focused energy transitions director thinking grid solar repair e waste

# %% [markdown]
# Let's choose a word and go. My choice in educai, as I am curious to see how this will form a lexicon. We'll need to create a lexicon list, and put the word in the list. Also, now is a good time to remember we will get a lot of Spanish and Portugese for this account.

# %%
start_word = 'educaci'
lexicon_list1 = []
lexicon_list1.append(start_word)

# %% [markdown]
# This is a crucial step. We want to create two groups text, one that includes our start word and one that doesn't. And we can take a look at the Tweet's that include that word.

# %%
CF_group_with_word1 = CF_descs[CF_descs['Clean'].str.contains(start_word, case=False, na=False)]
CF_group_NO_word1 = CF_descs[~CF_descs['Clean'].str.contains(start_word, case=False, na=False)]

CF_group_with_word1.head()
# Out:
#                                                                                                                                                            description  \
# 657           Campus virtual de Educación Ambiental.  Desde cualquier profesión, área de trabajo u oficio se puede ser parte de la lucha contra el #cambioclimático 🌎💻
# 1304  Periodista colombiano;  experiencia en proyectos de cultura, educación y medio ambiente. Fotografo. Mas aprendiz que experto. Entre el diletante y el militante.
# 2832                                                                                           Académica. Apasionada de los temas de educación superior universitaria.
# 3061                                                                                                                 Profesional en Educación Física!!  Yo ❤️ la EduFi
# 6506                                      Hijo, Esposo, Padre. Pasión por la investigación. Asesor en Tecnologías y Educación. Interesado en el comportamiento humano.
#
#                                                                                                                                                       Clean
# 657                   campus virtual de educaci n ambiental desde cualquier profesi n rea de trabajo u oficio se puede ser parte de la lucha contra el tico
# 1304  periodista colombiano experiencia en proyectos de cultura educaci n medio ambiente fotografo mas aprendiz que experto entre el diletante el militante
# 2832                                                                                  acad mica apasionada de los temas de educaci n superior universitaria
# 3061                                                                                                            profesional en educaci n f sica yo la edufi
# 6506                                      hijo esposo padre pasi n por la investigaci n asesor en tecnolog educaci n interesado en el comportamiento humano

# %% [markdown]
# Now we have a subgroup with our starting word and second subgroup that does not have the starting word. From there, we can do a group comparison of the most concentrated words to discover words important to our subgroup. Before we can run our comparison function, we want to make a list of words for each group.

# %%
with_word1 =' '.join([i for i in CF_group_with_word1['Clean']]).split()
no_word1 =' '.join([i for i in CF_group_NO_word1['Clean']]).split()
print(with_word1[:40])
# Out:
# ['campus', 'virtual', 'de', 'educaci', 'n', 'ambiental', 'desde', 'cualquier', 'profesi', 'n', 'rea', 'de', 'trabajo', 'u', 'oficio', 'se', 'puede', 'ser', 'parte', 'de', 'la', 'lucha', 'contra', 'el', 'tico', 'periodista', 'colombiano', 'experiencia', 'en', 'proyectos', 'de', 'cultura', 'educaci', 'n', 'medio', 'ambiente', 'fotografo', 'mas', 'aprendiz', 'que']

# %%
quick_compare(with_word1, no_word1)
# Out:
# {'One_vs_two': {'superior': 37.5601904929888,
#   'investigaci': 26.36266891409308,
#   'tecnolog': 17.19172898186552,
#   'acci': 15.997858913680416,
#   'ncia': 14.894558298943833,
#   'ii': 14.239852439649601,
#   'england': 13.168969227724732,
#   'cient': 12.341205447696318,
#   'profesor': 12.154217486367587,
#   'conservaci': 11.874699399845255},
#  'Two_vs_one': {'sustainability': 4.304147400516224,
#   'world': 3.2247370830838586,
#   'business': 3.204132473966588,
#   'working': 2.9994093111481197,
#   'health': 2.881172589488019,
#   'co': 2.5985620198137367,
#   'environmental': 2.5929395743082218,
#   'research': 2.549944402795458,
#   'policy': 2.4964760484783026,
#   'views': 2.4118724592977885}}

# %% [markdown]
# We want to specifically look at the One-vs-Two as we put our with_word1 list in the one spot. We can see that investigaci  are highly concentrated so lets pick those words, add to our lexicon list and run again.

# %%
lexicon_list1.append('investigaci')
lexicon_list1
# Out:
# ['educaci', 'investigaci']

# %%
words ="|".join(word for word in lexicon_list1)
CF_group_with_word2 = CF_descs[CF_descs['Clean'].str.contains(words, case=False, na=False, regex=True)]
CF_group_NO_word2 = CF_descs[~CF_descs['Clean'].str.contains(words, case=False, na=False)]

CF_group_with_word2.head()
# Out:
#                                                                                                                                                            description  \
# 657           Campus virtual de Educación Ambiental.  Desde cualquier profesión, área de trabajo u oficio se puede ser parte de la lucha contra el #cambioclimático 🌎💻
# 1304  Periodista colombiano;  experiencia en proyectos de cultura, educación y medio ambiente. Fotografo. Mas aprendiz que experto. Entre el diletante y el militante.
# 2832                                                                                           Académica. Apasionada de los temas de educación superior universitaria.
# 3061                                                                                                                 Profesional en Educación Física!!  Yo ❤️ la EduFi
# 4816     Somos una fundación dedicada a la investigación, formación, asesoría y ejecución de planes, programas y proyectos en la búsqueda de enfrentar la desigualdad.
#
#                                                                                                                                                       Clean
# 657                   campus virtual de educaci n ambiental desde cualquier profesi n rea de trabajo u oficio se puede ser parte de la lucha contra el tico
# 1304  periodista colombiano experiencia en proyectos de cultura educaci n medio ambiente fotografo mas aprendiz que experto entre el diletante el militante
# 2832                                                                                  acad mica apasionada de los temas de educaci n superior universitaria
# 3061                                                                                                            profesional en educaci n f sica yo la edufi
# 4816      somos una fundaci n dedicada la investigaci n formaci n asesor ejecuci n de planes programas proyectos en la b squeda de enfrentar la desigualdad

# %%
with_word2 =' '.join([i for i in CF_group_with_word2['Clean']]).split()
no_word2 =' '.join([i for i in CF_group_NO_word2['Clean']]).split()
#print(with_word2[:100])

# %%
#runs our comparison 
quick_compare(with_word2, no_word2, num_words=20)
# Out:
# {'One_vs_two': {'docencia': 69.68123598611665,
#   'centro': 33.791201788448134,
#   'superior': 31.810999037140213,
#   'cient': 20.63636604204224,
#   'acci': 19.44005496714124,
#   'fica': 18.16159874106232,
#   'tecnolog': 15.58659226005241,
#   'profesor': 12.92102389146534,
#   'ncia': 12.614706514728015,
#   'estado': 12.400897929732626,
#   'ii': 12.060213920674036,
#   'docente': 11.870476041882705,
#   'organizaci': 11.47690945653686,
#   'proyectos': 11.457652897046028,
#   'conservaci': 11.432077778972262,
#   'ambiental': 11.338075874401333,
#   'england': 11.153246613631477,
#   'cultura': 10.161846914642013,
#   'ster': 9.380166382746474,
#   'ciencia': 9.261430099420568},
#  'Two_vs_one': {'sustainability': 5.0820345530344415,
#   'world': 3.8075427618297,
#   'business': 3.783214288443036,
#   'working': 3.5414915753395846,
#   'health': 3.4018859696295944,
#   'environmental': 3.0615606958498556,
#   'policy': 2.947663348534013,
#   'views': 2.847769380340792,
#   'phd': 2.7185018857345375,
#   'co': 2.683649297455889,
#   'sustainable': 2.656997318183982,
#   'people': 2.574991228116575,
#   'food': 2.5736244599487854,
#   'opinions': 2.5408220239218227,
#   'former': 2.5052860515592794,
#   'change': 2.474631394081701,
#   'tweets': 2.393947013890839,
#   'politics': 2.3863772209615393,
#   'love': 2.3855571600608654,
#   'global': 2.3283872001281587}}

# %%
lexicon_list1.append('docencia')
words ="|".join(word for word in lexicon_list1)  
CF_group_with_word3 = CF_descs[CF_descs['Clean'].str.contains(words, case=False, na=False, regex=True)]
CF_group_NO_word3 = CF_descs[~CF_descs['Clean'].str.contains(words, case=False, na=False)]
CF_group_with_word3
# Out:
#                                                                                                                                                              description  \
# 657             Campus virtual de Educación Ambiental.  Desde cualquier profesión, área de trabajo u oficio se puede ser parte de la lucha contra el #cambioclimático 🌎💻
# 1304    Periodista colombiano;  experiencia en proyectos de cultura, educación y medio ambiente. Fotografo. Mas aprendiz que experto. Entre el diletante y el militante.
# 2832                                                                                             Académica. Apasionada de los temas de educación superior universitaria.
# 3061                                                                                                                   Profesional en Educación Física!!  Yo ❤️ la EduFi
# 3084                                                                                                              Familia, docencia, biología, lectura, fotografía, aves
# ...                                                                                                                                                                  ...
# 156070                                                                                    Sembrando empatía 🌱 Educación - Biodiversidad - Ecosistemas - Cambio Climático
# 156102  El CIET fue creado en 1977 por un acuerdo entre la UNESCO y  Venezuela.Una de las principales metas del CIET es promover la investigación científica en ecología
# 156485            intereses: Educación - Salud Holística-Relaciones Intls-Comunicación-yoga-cocina-Patrimonio cultural- bienestar animal-TEFL-ESL- 0% alcohol al volante
# 156892             Biologa, M.C.en Ecol y Cienc. Amb.  Máster en Agroecología. Investigación Acción Socio-Ecológica, Soberanía Alimentaria, Desarrollo Rural Sustentable
# 157533                                             De origen rural y educacion universitaria tecnologica desarrollando proyectos de obra y estudios de  competitividad .
#
#                                                                                                                                                          Clean
# 657                      campus virtual de educaci n ambiental desde cualquier profesi n rea de trabajo u oficio se puede ser parte de la lucha contra el tico
# 1304     periodista colombiano experiencia en proyectos de cultura educaci n medio ambiente fotografo mas aprendiz que experto entre el diletante el militante
# 2832                                                                                     acad mica apasionada de los temas de educaci n superior universitaria
# 3061                                                                                                               profesional en educaci n f sica yo la edufi
# 3084                                                                                                             familia docencia biolog lectura fotograf aves
# ...                                                                                                                                                        ...
# 156070                                                                                    sembrando empat educaci n biodiversidad ecosistemas cambio clim tico
# 156102  el ciet fue creado en por un acuerdo entre la unesco venezuela una de las principales metas del ciet es promover la investigaci n cient fica en ecolog
# 156485          intereses educaci n salud hol stica relaciones intls comunicaci n yoga cocina patrimonio cultural bienestar animal tefl esl alcohol al volante
# 156892                    biologa c en ecol cienc amb ster en agroecolog investigaci n acci n socio ecol gica soberan alimentaria desarrollo rural sustentable
# 157533                                          de origen rural educacion universitaria tecnologica desarrollando proyectos de obra estudios de competitividad
#
# [274 rows x 2 columns]

# %% [markdown]
# We can run our function to get the concentrations of interesting words one last time.

# %%
with_word3 =' '.join([i for i in CF_group_with_word3['Clean']]).split()
no_word3 =' '.join([i for i in CF_group_NO_word3['Clean']]).split()
quick_compare(with_word3, no_word3, num_words=20)
# Out:
# {'One_vs_two': {'superior': 45.6330094352908,
#   'centro': 33.193890899466055,
#   'cient': 20.271586883754182,
#   'acci': 19.096422426724956,
#   'fica': 17.84056485900997,
#   'tecnolog': 15.311075534209415,
#   'profesor': 13.575820306999015,
#   'ncia': 12.391722389755692,
#   'estado': 12.181693196708984,
#   'proyectos': 12.140538827801185,
#   'ambiental': 12.13899127664404,
#   'ii': 11.847031295700496,
#   'docente': 11.660647322513467,
#   'organizaci': 11.274037625189493,
#   'conservaci': 11.229998415716096,
#   'england': 10.956096015332776,
#   'finanzas': 10.727162665758659,
#   'turismo': 9.982220813969864,
#   'cultura': 9.982220813969862,
#   'ciencia': 9.91863978967706},
#  'Two_vs_one': {'sustainability': 5.173483747282397,
#   'world': 3.876057982259686,
#   'business': 3.8512917276526712,
#   'working': 3.605219310289231,
#   'health': 3.4631015571269863,
#   'environmental': 3.1166522651524504,
#   'policy': 3.000705380288148,
#   'views': 2.89901385979453,
#   'phd': 2.7674202479411716,
#   'co': 2.7319405011726947,
#   'sustainable': 2.704808930114448,
#   'people': 2.6213271730121503,
#   'food': 2.6199358103937787,
#   'opinions': 2.5865431075528598,
#   'former': 2.550367679475197,
#   'change': 2.519161403606005,
#   'tweets': 2.4370251400247698,
#   'politics': 2.4293191316768654,
#   'love': 2.4284843141058423,
#   'global': 2.3702856034402404}}

# %% [markdown]
# From looking at the ratios, we can add a few more words to fill out the lexicon. Admittedly, it's a lot harder to do this when it's in another language.

# %%
lexicon_list1 = lexicon_list1 + ['superior', 'ambiental']
print(f'Our final lexicon for our subgroup we determined')
lexicon_list1
# Out:
# Our final lexicon for our subgroup we determined
# ['educaci', 'investigaci', 'docencia', 'superior', 'ambiental']

# %%
words ="|".join(word for word in lexicon_list1)  
CF_group_with_word_final = CF_descs[CF_descs['Clean'].str.contains(words, case=False, na=False, regex=True)]
CF_group_NO_word_final = CF_descs[~CF_descs['Clean'].str.contains(words, case=False, na=False)]
CF_with_word=' '.join([i for i in CF_group_with_word_final['Clean']]).split()
CF_no_word =' '.join([i for i in CF_group_NO_word_final['Clean']]).split()

# %% [markdown]
# ##  Second Group
#
# Now let's do the same for EcoSenseNow's followers.

# %%
pd.set_option('display.max_colwidth', None)

ESN = pd.read_csv('EcoSenseNow_followers.txt', encoding='utf8', header = 0, sep='\t', on_bad_lines='skip', lineterminator='\r',
                   dtype={"screen_name": str,
                          "user_id": str,
                          "name": str,
                          "location": str,
                          "followers_count": str,
                          "friends_count": str,
                          "description": str})


ESN_followers = ESN.dropna(axis = 0, subset=['description'])
ESN_followers
# Out:
#               screen_name                      name            ID  \
# 0          \nnotfakhongs1                John Smith  1.456148e+18
# 1           \nadios_mafia               Adios Mafia  8.245604e+17
# 2               \npgillam               paul gillam  4.604376e+07
# 3          \nDenningJimbo             Jimbo Denning  1.456665e+18
# 4           \nWayneWwoods               wayne woods  5.115411e+08
# ...                   ...                       ...           ...
# 100838  \nprometheusgreen              Val Giddings  1.151363e+09
# 100839   \nDiscoveryFarms           Discovery Farms  3.347478e+08
# 100840   \nLucas_MN_Dairy            Lucas Sjostrom  1.815640e+07
# 100841          \ncga_acg  Canadian Gas Association  2.736227e+08
# 100842  \nNorthernGateway          Northern Gateway  1.907893e+07
#
#                        Location  Followers_Count  Friends_Count  \
# 0                           NaN             11.0          483.0
# 1              North Haverbrook           1216.0          344.0
# 2         Peterborough, Ontario            439.0         1467.0
# 3                           NaN             36.0          208.0
# 4                        Alaska           1513.0         4093.0
# ...                         ...              ...            ...
# 100838                      NaN           5104.0         5353.0
# 100839  Pigeon Falls, Wisconsin           1126.0         1231.0
# 100840               brooten mn           2009.0         1742.0
# 100841                      NaN           4765.0         2363.0
# 100842                   Canada           8524.0         1729.0
#
#                                                                                                                                                             description
# 0                                                                      Banned for saying Colin Powell should have been nixed for war crimes, been on twitter since 2013
# 1       Always blindly follow calls 'cos DYOR is boring, very interested in looking cool on social media, more important than irl success tbh. This account = very good
# 2                                                                    My tweets are my own. I may not agree 100% with retweets. BBM Channel, Leadership Quotes C00069417
# 3                                                                                            Twit twitter twoo. It's amazing what you can get suspended for these days.
# 4                                                                                   Gold Star father. Disciple. Purveyor of the manly arts. IMI for life. Jesus Reigns!
# ...                                                                                                                                                                 ...
# 100838   ITIF life sci guru, keynote speaker, professional skeptic, biotech expert, policy wonk, beekeeper, lover of wilderness. will travel miles for dark night skies
# 100839                                                             Program of @UWMadisonExt working with farmers across Wisconsin on water quality and farm management.
# 100840              Dairy farmer, exec director @mnmilk and @midwestdairy, tour guide @redheadcreamery. Husband of @amsjost. Tweets mine unless they're someone else's.
# 100841         Over 20 million Canadians in homes, businesses, schools, hospitals, and industry use affordable, clean, safe, and reliable natural gas energy solutions.
# 100842               This is the official Twitter account for Northern Gateway Pipelines. Please join the conversation. Tweets by Northern Gateway communications team.
#
# [64879 rows x 7 columns]

# %%
# Convert to correct data types
ESN_followers = ESN_followers.convert_dtypes(infer_objects=True, convert_string=True, convert_integer=True, convert_boolean=True, convert_floating=True)
    
ESN_descs = ESN_followers['description']

ESN_clean_descs = []
for desc in ESN_descs:
    temp = desc.lower()
    temp = re.sub("@[A-Za-z0-9_]+", "", temp)
    temp = re.sub("#[A-Za-z0-9_]+", "", temp)
    temp = re.sub(r"http\S+", "", temp)
    temp = re.sub(r"www.\S+", "", temp)
    temp = re.sub('[()|!?]', ' ', temp)
    temp = re.sub('\[.*?\]', ' ', temp)
    temp = re.sub("[^a-z0-9]", " ", temp)
    temp = re.sub(r"[0-9]", " ", temp)
    temp = temp.split()
    temp =[w for w in temp if not w in sw]
    temp = " ".join(word for word in temp)
    ESN_clean_descs.append(temp)
    
    
print(ESN_clean_descs[:10])
# Out:
# ['banned saying colin powell nixed war crimes twitter since', 'always blindly follow calls cos dyor boring interested looking cool social media important irl success tbh account good', 'tweets may agree retweets bbm channel leadership quotes c', 'twit twitter twoo amazing get suspended days', 'gold star father disciple purveyor manly arts imi life jesus reigns', 'ear learner market', 'writer photographer psychologist retired teacher lover sciences art romance quantum physics nerd', 'pension r och sd sedan', 'sports news laugh political entertainment care opinions expect care mine xrp csc xdc', 'carbon based sombitch']

# %% [markdown]
# Let's put the clean Twitter descriptions back in our dataframe.

# %%
ESN_descs = ESN_descs.to_frame()
ESN_descs['Clean'] = ESN_clean_descs
ESN_descs.head()
# Out:
#                                                                                                                                                        description  \
# 0                                                                 Banned for saying Colin Powell should have been nixed for war crimes, been on twitter since 2013
# 1  Always blindly follow calls 'cos DYOR is boring, very interested in looking cool on social media, more important than irl success tbh. This account = very good
# 2                                                               My tweets are my own. I may not agree 100% with retweets. BBM Channel, Leadership Quotes C00069417
# 3                                                                                       Twit twitter twoo. It's amazing what you can get suspended for these days.
# 4                                                                              Gold Star father. Disciple. Purveyor of the manly arts. IMI for life. Jesus Reigns!
#
#                                                                                                                      Clean
# 0                                                                banned saying colin powell nixed war crimes twitter since
# 1  always blindly follow calls cos dyor boring interested looking cool social media important irl success tbh account good
# 2                                                                tweets may agree retweets bbm channel leadership quotes c
# 3                                                                             twit twitter twoo amazing get suspended days
# 4                                                      gold star father disciple purveyor manly arts imi life jesus reigns

# %%
ESN_descs.sample(50)
# Out:
#                                                                                                                                                          description  \
# 23981      Just another well balanced community minded guy, who loves animals, hugs trees and believes in ‘Equal Rights And Justice for All Earthbound Inhabitants’.
# 38940                                                                              I am single mother of beautiful boy.... I am simple loyal and honest to move with
# 41953       • Co-founder @HumaneTech_ • Former Google Design Ethicist  • Featured in Netflix's @SocialDilemma_ • #TIME100Next • Host #YourUndividedAttention podcast
# 32766                                                       Carbonate geologist | Passionate about ➡ motorcycles 🏍 , snowmobiles, post-hardcore/metalcore 🎶, #Ravens
# 26792                                                                                                                          A perfect contradiction Book Devourer
# 92439                                                            Space Shuttle Door Gunner (Ret.), Chicken Gun Firing Coordinator(Ret.), Conservative not Republican
# 24127                                                                                                                              Saskatchewan Roughriders Sect.618
# 99510   Calling All Ears for Prosperity & Sustainable Government. My tweets for policy & politics. Views tweeted are strictly my own & not attributable to any cows.
# 42294                                                                                                                                            . #Blacklivesmatter
# 87306                                                                                                                                                      Wonderer.
# 90876                                                                         Sky News producer | Formerly Today Show & 2GB | Water baby & butter chicken enthusiast
# 50760                                                    Supporting entertainment businesses to find the best products in Brazil, Uruguay and other countries in SA.
# 4603                                                   Multi Media Artist & Musician - Pod: @Yourthoughtspod Patreon: https://t.co/pbYri2jo1t RT’s not endorsements.
# 27747                                                                     I'm a Canadian. Huge fan of the Blue Jays, love my dog, summer and a proud conservative 🐶⚾
# 27656      #VT Senate candidate (R-Bennington) | Trained in medicine, Dartmouth alumna, health & economic policy chops | TCK + #Vermonter | Not allowed near Nutella
# 59864                                                                    Fluent in sarcasm. Dad to twin boys, Texas Tech Alumni, Conservative, Christian, Sports Fan
# 20718                                                                                          Not left or Religious. Resident since1066. love Europe But Detest EU.
# 77187                                        Deep Sea Fishing, Cars, Fine Art, Fine wine and Real Estate!, All tweets are my own Retweets or links don't=endorsement
# 57206          For the despondent everyday brings troubles; for the happy heart, life is a continual feast.  Prov15:15.   My fellow humans find your happy heart!!❤️
# 79336                                                                      Gelukkig getrouwd en fiere vader. Barely twittering, often spreading my wings. Let's fly.
# 6828                                                     “There must have been a moment, at the beginning, where we could have said...no. But somehow we missed it.”
# 44810           Energy Advocate   |   Leader   |   Strategic Thinker   |   People-Connector   |   Problem-Solver   |   Writer   |   Politically engaged non-partisan
# 51323                                                                                                                                Associate Professor, BYU-Hawaii
# 58643                It is all about saving our children!  Proud American.  Loves 1st Responders & Military.  Believes in the Power of Prayer.  Love & Light to all!
# 3152                                                              raised in a rural part of Ireland. He writes on the crossover of culture, economics, and politics.
# 49075                                                                                   Love is like communism.. Everyone gets a share and it's only good in theory.
# 11132                                                                               Lover of liberty and common sense. Flower gardener, arch enemy of Bermuda grass.
# 92496     Termo is a California based Independent Oil & Gas Exploration & Production company founded in 1933. Follows & retweets are for information & conversation.
# 56020                                           Follows, likes, and retweets are not endorsements; Don't assume too much: I don't agree with anybody, including you.
# 23418                                                mother, sister, aunt, great aunt, cousin, friend, woman, teacher, assistant head of faculty, head of geography.
# 68008                                     Wanderer, love science and exploration. English, Secularist, Brexiteer. Anti the violent political ideology that is Islam.
# 75906                                                                            self employed, BBQ fan, diehard bills fan ,Buffalo Sabres fan, I like to cook stuff
# 39128                                     La differenza fra un cambio fisso e una guerra civile non salta all'occhio. Perché non c'è. Un giorno capirete (A. Bagnai)
# 42046                                          America Will Be Stronger. Country & History 💰MAGA 🇺🇸KAG💰 🇺🇸Trump 2020🇺🇸. Married 35 Year To My Beautiful Doll NO DM’s
# 76413                                                                                                                  Libertarian | Venerable armchair philosopher.
# 79315                                                                                                                                           Still working on it.
# 92699     I don't argue, I debate. CC isn't a threat, knee jerk humans are. Wind/Solar are problems, Thorium, the answer. socialism is dying. Vicious when provoked.
# 9956                                                                                      To stop the country from imploding from liberalism, socialism, communism..
# 16749                                                                         COVID-19, Climate, Public Health, & Economics.  Data, Transparency, Science, Solutions
# 688                                                                                                                                                            ❤️❤️🙌
# 1952                                                                                                      Lover of truth and ice cream, Hater of laziness and snakes
# 32404                                                                                                                      Skeptisk skånska, rätt så vrång. Preppar.
# 30953                                                                                                                                       the world, a scary space
# 12576                                                                                                                                 Work, play, read, sleep, LIVE!
# 36533                                                                                               B,stoke Canal Photography Natural fabrics Crafts Political stuff
# 35423                                                                                                             I'm an albino, a gringo...& a hardcore autodidact.
# 74446  COO: @Probellum; Board Advisor: @GamingSociety & @BettingAcademy; Former CEO (@Rivals), SVP (@UFC). Former Advisor @SeatGeek (4 years) & @ActionApp (2 years)
# 7735                                                                                                                                                        #bitcoin
# 61229                                                                                    My feelings. My opinions. Deal with it. #GoMariners, #GoCougs, #GoHawks #2A
# 6279                                               Descubriendo el presente, viviendo el futuro.  Doctor #biotecnología. MBA in progress. Profesional independiente.
#
#                                                                                                                              Clean
# 23981     another well balanced community minded guy loves animals hugs trees believes equal rights justice earthbound inhabitants
# 38940                                                                         single mother beautiful boy simple loyal honest move
# 41953                                                       co founder former google design ethicist featured netflix host podcast
# 32766                                               carbonate geologist passionate motorcycles snowmobiles post hardcore metalcore
# 26792                                                                                          perfect contradiction book devourer
# 92439                                     space shuttle door gunner ret chicken gun firing coordinator ret conservative republican
# 24127                                                                                                saskatchewan roughriders sect
# 99510               calling ears prosperity sustainable government tweets policy politics views tweeted strictly attributable cows
# 42294
# 87306                                                                                                                     wonderer
# 90876                                                sky news producer formerly today show gb water baby butter chicken enthusiast
# 50760                                           supporting entertainment businesses find best products brazil uruguay countries sa
# 4603                                                                       multi media artist musician pod patreon rt endorsements
# 27747                                                               canadian huge fan blue jays love dog summer proud conservative
# 27656        senate candidate r bennington trained medicine dartmouth alumna health economic policy chops tck allowed near nutella
# 59864                                             fluent sarcasm dad twin boys texas tech alumni conservative christian sports fan
# 20718                                                                          left religious resident since love europe detest eu
# 77187                                       deep sea fishing cars fine art fine wine real estate tweets retweets links endorsement
# 57206                     despondent everyday brings troubles happy heart life continual feast prov fellow humans find happy heart
# 79336                                             gelukkig getrouwd en fiere vader barely twittering often spreading wings let fly
# 6828                                                                               must moment beginning could said somehow missed
# 44810             energy advocate leader strategic thinker people connector problem solver writer politically engaged non partisan
# 51323                                                                                               associate professor byu hawaii
# 58643                                 saving children proud american loves st responders military believes power prayer love light
# 3152                                                         raised rural part ireland writes crossover culture economics politics
# 49075                                                                          love like communism everyone gets share good theory
# 11132                                                          lover liberty common sense flower gardener arch enemy bermuda grass
# 92496  termo california based independent oil gas exploration production company founded follows retweets information conversation
# 56020                                                      follows likes retweets endorsements assume much agree anybody including
# 23418                              mother sister aunt great aunt cousin friend woman teacher assistant head faculty head geography
# 68008                         wanderer love science exploration english secularist brexiteer anti violent political ideology islam
# 75906                                                   self employed bbq fan diehard bills fan buffalo sabres fan like cook stuff
# 39128                 la differenza fra un cambio fisso e una guerra civile non salta occhio perch non c un giorno capirete bagnai
# 42046                                               america stronger country history maga kag trump married year beautiful doll dm
# 76413                                                                                   libertarian venerable armchair philosopher
# 79315                                                                                                                still working
# 92699                  argue debate cc threat knee jerk humans wind solar problems thorium answer socialism dying vicious provoked
# 9956                                                                         stop country imploding liberalism socialism communism
# 16749                                                    covid climate public health economics data transparency science solutions
# 688
# 1952                                                                                   lover truth ice cream hater laziness snakes
# 32404                                                                                          skeptisk sk nska r tt vr ng preppar
# 30953                                                                                                            world scary space
# 12576                                                                                                    work play read sleep live
# 36533                                                             b stoke canal photography natural fabrics crafts political stuff
# 35423                                                                                            albino gringo hardcore autodidact
# 74446                                                                  coo board advisor former ceo svp former advisor years years
# 7735
# 61229                                                                                                       feelings opinions deal
# 6279                                     descubriendo el presente viviendo el futuro doctor mba progress profesional independiente

# %% [markdown]
# Since these followers are in English, it'll be easier. Also, it's notably hard to find education focused words. But interesting, we see a of interesting words...some not so surprising for followers of an ant-climate scientist.

# %%
start_word = 'academic'
lexicon_list2 = []
lexicon_list2.append(start_word)

# %%
ESN_group_with_word1 = ESN_descs[ESN_descs['Clean'].str.contains(start_word, case=False, na=False)]
ESN_group_NO_word1 = ESN_descs[~ESN_descs['Clean'].str.contains(start_word, case=False, na=False)]

ESN_group_with_word1.head()
# Out:
#                                                                                                                                                         description  \
# 965   Academic interests: #Extremism and #CT | @BrockUniversity #Philosophy | Found with espresso and never enough books | @HdxAcademy | Podcast🎙: @Modesofinquiry.
# 1270                                                                                                                  Academic, golfer, husband, father, loves data
# 1708                                                                   Disgracefully growing old hedonist, urban cyclist, business professional, academic & writer.
# 4078                                                                           Academic, PhD.  Superpower: reading the primary source data, studies, and documents.
# 6200                   Former Greater Manchester firefighter, FE and HE lecturer in politics, social science and public services. Academic freedom and free speech.
#
#                                                                                                                        Clean
# 965                                                             academic interests found espresso never enough books podcast
# 1270                                                                               academic golfer husband father loves data
# 1708                                  disgracefully growing old hedonist urban cyclist business professional academic writer
# 4078                                                   academic phd superpower reading primary source data studies documents
# 6200  former greater manchester firefighter fe lecturer politics social science public services academic freedom free speech

# %%
with_word1 =' '.join([i for i in ESN_group_with_word1['Clean']]).split()
no_word1 =' '.join([i for i in ESN_group_NO_word1['Clean']]).split()
print(with_word1[:200])
# Out:
# ['academic', 'interests', 'found', 'espresso', 'never', 'enough', 'books', 'podcast', 'academic', 'golfer', 'husband', 'father', 'loves', 'data', 'disgracefully', 'growing', 'old', 'hedonist', 'urban', 'cyclist', 'business', 'professional', 'academic', 'writer', 'academic', 'phd', 'superpower', 'reading', 'primary', 'source', 'data', 'studies', 'documents', 'former', 'greater', 'manchester', 'firefighter', 'fe', 'lecturer', 'politics', 'social', 'science', 'public', 'services', 'academic', 'freedom', 'free', 'speech', 'kentucky', 'born', 'buried', 'see', 'digital', 'wasteland', 'people', 'wanted', 'academic', 'college', 'happened', 'pronouns', 'dead', 'jim', 'academic', 'secular', 'humanist', 'ex', 'academic', 'wife', 'mother', 'libertarian', 'monotonously', 'alike', 'great', 'tyrants', 'conquerors', 'gloriously', 'different', 'saints', 'cs', 'lewis', 'ex', 'academic', 'ex', 'burger', 'flipper', 'permaculture', 'gardener', 'flamencomane', 'tyrannophobe', 'erratic', 'midnight', 'gab', 'today', 'way', 'find', 'great', 'jobs', 'careers', 'higher', 'education', 'visit', 'site', 'daily', 'best', 'academic', 'jobs', 'higher', 'ed', 'events', 'academic', 'excellence', 'full', 'scholarship', 'awarded', 'medical', 'doctor', 'specialist', 'consultant', 'obstetrics', 'gynaecology', 'speed', 'reader', 'asks', 'god', 'help', 'f', 'unpaid', 'carer', 'mum', 'p', 'academic', 'science', 'tweets', 'self', 'destruct', 'within', 'days', 'range', 'academic', 'cultural', 'interests', 'fellow', 'several', 'learned', 'societies', 'always', 'politically', 'correct', 'lockdowns', 'unethical', 'illegal', 'confuse', 'academic', 'scientist', 'tweets', 'auto', 'delete', 'months', 'always', 'searching', 'truth', 'science', 'philosophy', 'academic', 'freedom', 'looking', 'learn', 'sharing', 'thoughts', 'challenged', 'hungarian', 'postgrad', 'student', 'history', 'religious', 'studies', 'pinch', 'comparative', 'linguistics', 'mythology', 'fighting', 'academic', 'dogma', 'propaganda', 'free', 'thinking', 'brexiteer', 'suspicious', 'cultural', 'marxism', 'top', 'politics', 'retirement', 'linux', 'ruby', 'nodejs', 'academic', 'maths', 'uk', 'nigeria']

# %%
quick_compare(with_word1, no_word1, num_words=20)
# Out:
# {'One_vs_two': {'netherlands': 34.755077422034134,
#   'columbia': 26.14057105247012,
#   'calgary': 11.028053412760832,
#   'alberta': 7.98550081759531,
#   'london': 6.742607612740308,
#   'england': 6.620014747054121,
#   'ca': 6.559169023276049,
#   'msc': 6.535142763117529,
#   'california': 5.706057487199633,
#   'usa': 4.941368150479683,
#   'education': 4.207768807384635,
#   'canada': 4.191950127657625,
#   'united': 3.8616752691149037,
#   'british': 3.6540583191624894,
#   'engineering': 2.9984772677833367,
#   'g': 2.9183652797127895,
#   'uk': 2.593159846411462,
#   'books': 2.5151700765945755,
#   'van': 2.48481054920764,
#   'p': 2.37246539139772},
#  'Two_vs_one': {'father': 2.6905813645829775,
#   'proud': 2.560776916686582,
#   'family': 2.3005140942041358,
#   'conservative': 2.1948395411559867,
#   'people': 2.140955981928465,
#   'love': 2.026367905079796,
#   'like': 1.94347012165284,
#   'fan': 1.910337836043684,
#   'god': 1.8911559864804888,
#   'dad': 1.8519203851012256,
#   'husband': 1.732251800894473,
#   'good': 1.6557423782049094,
#   'one': 1.6151989234463373,
#   'freedom': 1.508608873032672,
#   'engineer': 1.3850167286879929,
#   'right': 1.3706303415155965,
#   'en': 1.3313947401363333,
#   'world': 1.3238091905363423,
#   'living': 1.1927622819296029,
#   'libertarian': 1.1535266805503397}}

# %% [markdown]
# Let's pick a couple words. Interestingly, we are getting a lot of numbers for this group. So I removed numbers from the text.

# %%
lexicon_list2.append('netherlands')

lexicon_list2
# Out:
# ['academic', 'netherlands']

# %%
words ="|".join(word for word in lexicon_list2)
ESN_group_with_word2 = ESN_descs[ESN_descs['Clean'].str.contains(words, case=False, na=False, regex=True)]
ESN_group_NO_word2 = ESN_descs[~ESN_descs['Clean'].str.contains(words, case=False, na=False)]

ESN_group_with_word2.head()
# Out:
#                                                                                                                                                         description  \
# 965   Academic interests: #Extremism and #CT | @BrockUniversity #Philosophy | Found with espresso and never enough books | @HdxAcademy | Podcast🎙: @Modesofinquiry.
# 1270                                                                                                                  Academic, golfer, husband, father, loves data
# 1708                                                                   Disgracefully growing old hedonist, urban cyclist, business professional, academic & writer.
# 3812                                                                                                      Texas ➡️ Ireland ➡️ Netherlands. Also tweets for @b4place
# 4078                                                                           Academic, PhD.  Superpower: reading the primary source data, studies, and documents.
#
#                                                                                        Clean
# 965                             academic interests found espresso never enough books podcast
# 1270                                               academic golfer husband father loves data
# 1708  disgracefully growing old hedonist urban cyclist business professional academic writer
# 3812                                                   texas ireland netherlands also tweets
# 4078                   academic phd superpower reading primary source data studies documents

# %%
with_word2 =' '.join([i for i in ESN_group_with_word2['Clean']]).split()
no_word2 =' '.join([i for i in ESN_group_NO_word2['Clean']]).split()
print(with_word2[:100])
# Out:
# ['academic', 'interests', 'found', 'espresso', 'never', 'enough', 'books', 'podcast', 'academic', 'golfer', 'husband', 'father', 'loves', 'data', 'disgracefully', 'growing', 'old', 'hedonist', 'urban', 'cyclist', 'business', 'professional', 'academic', 'writer', 'texas', 'ireland', 'netherlands', 'also', 'tweets', 'academic', 'phd', 'superpower', 'reading', 'primary', 'source', 'data', 'studies', 'documents', 'director', 'netherlands', 'gazelle', 'global', 'interests', 'people', 'recruitment', 'sourcing', 'ict', 'sales', 'agile', 'scrum', 'politics', 'wife', 'kids', 'former', 'greater', 'manchester', 'firefighter', 'fe', 'lecturer', 'politics', 'social', 'science', 'public', 'services', 'academic', 'freedom', 'free', 'speech', 'kentucky', 'born', 'buried', 'see', 'digital', 'wasteland', 'people', 'wanted', 'academic', 'college', 'happened', 'pronouns', 'dead', 'jim', 'academic', 'secular', 'humanist', 'ex', 'academic', 'wife', 'mother', 'libertarian', 'monotonously', 'alike', 'great', 'tyrants', 'conquerors', 'gloriously', 'different', 'saints', 'cs', 'lewis']

# %%
quick_compare(with_word2, no_word2, num_words=40)
# Out:
# {'One_vs_two': {'dennis': 32.5325837428867,
#   'ryan': 26.557211218683022,
#   'greg': 24.786730470770824,
#   'belgium': 23.660060903917604,
#   'jay': 22.30805742369374,
#   'queensland': 21.24576897494642,
#   'williams': 18.59004785307812,
#   'kevin': 18.590047853078115,
#   'brian': 18.590047853078115,
#   'columbia': 17.428169862260734,
#   'daniel': 17.350711329539575,
#   'rob': 15.934326731209815,
#   'chris': 15.147446398804393,
#   'steve': 14.606466170275663,
#   'ct': 14.458926107949647,
#   'mike': 13.83445421624418,
#   'david': 13.409214844843232,
#   'michael': 12.657053857414887,
#   'matt': 12.393365235385412,
#   'scott': 12.393365235385412,
#   'nederland': 12.028854493168193,
#   'eric': 11.830030451958802,
#   'tim': 11.538650391565728,
#   'ontario': 11.15402871184687,
#   'cape': 10.62288448747321,
#   'tony': 10.140026101678973,
#   'peter': 10.140026101678972,
#   'tx': 9.442563988865075,
#   'england': 9.152023558438456,
#   'richard': 9.043807063659624,
#   'calgary': 8.988594566323485,
#   'toronto': 8.637800012541348,
#   'martin': 8.26224349025694,
#   'tom': 8.038939612141888,
#   'robert': 7.886686967972534,
#   'ga': 7.886686967972534,
#   'germany': 7.654725586561578,
#   'states': 7.6351982253713695,
#   'jim': 7.436019141231246,
#   'wales': 7.436019141231246},
#  'Two_vs_one': {'trump': 3.4128177047128685,
#   'make': 3.096414837386708,
#   'work': 3.0885701381968036,
#   'writer': 2.973941472483092,
#   'everything': 2.9271934691473334,
#   'back': 2.904780042890463,
#   'get': 2.719869276271278,
#   'supporter': 2.612765117943802,
#   'political': 2.5793370936406976,
#   'tech': 2.5685786490374,
#   'pro': 2.5416825375291547,
#   'food': 2.520549878486962,
#   'let': 2.5058210555181613,
#   'american': 2.478924944009916,
#   'live': 2.3776162573288597,
#   'small': 2.3758231832283103,
#   'years': 2.346685729094378,
#   'president': 2.328434796285212,
#   'support': 2.2951348487035754,
#   'first': 2.240061858472407,
#   'music': 2.217894733602974,
#   'things': 2.21444651417884,
#   'teacher': 2.187550402670595,
#   'history': 2.18665386562032,
#   'patriot': 2.146309698357953,
#   'old': 2.1449648927825407,
#   'dad': 2.0978966976431117,
#   'fan': 2.0863697927110065,
#   'day': 2.074362600073397,
#   'catholic': 2.0710005861348666,
#   'liberty': 2.062931752682393,
#   'engineer': 2.019129513940394,
#   'owner': 2.0172083631183764,
#   'health': 2.0133660614743416,
#   'christian': 2.00929774208654,
#   'love': 1.987323794775882,
#   'good': 1.9855658789910298,
#   'libertarian': 1.9634161401018866,
#   'freedom': 1.95317000238446,
#   'farmer': 1.944588862046115}}

# %%
lexicon_list2.append('england')
words ="|".join(word for word in lexicon_list2)  
ESN_group_with_word3 = ESN_descs[ESN_descs['Clean'].str.contains(words, case=False, na=False, regex=True)]
ESN_group_NO_word3 = ESN_descs[~ESN_descs['Clean'].str.contains(words, case=False, na=False)]
ESN_group_with_word3
# Out:
#                                                                                                                                                           description  \
# 611                                                                      On a winters afternoon. In a secluded chapel, history is now and England.  Traditionalist...
# 965     Academic interests: #Extremism and #CT | @BrockUniversity #Philosophy | Found with espresso and never enough books | @HdxAcademy | Podcast🎙: @Modesofinquiry.
# 999                                                         Guatemala - Texas A&M - Real Madrid - New England Patriots  -                              Options Trader
# 1052                                                                      Leeds,West Riding of Yorkshire,England,UK,centre right.......lover of rock music!.......👺🤘🎸
# 1270                                                                                                                    Academic, golfer, husband, father, loves data
# ...                                                                                                                                                               ...
# 97733         Haydon Manning is a “retired” academic; for four decades he taught Australian politics and electoral behaviour at Flinders University, South Australia.
# 97989           Scientific Research Publishing (SCIRP) is an academic publisher of open access journals. It also publishes academic books and conference proceedings.
# 99376                       Father, @TDEM meteorologist, skier, hockey player, #FSU alumnus, native New Englander, naturalized Texan. #IamSecond #TXwx #Noles #skiing
# 100594  Scientist. Dad to 4. Recovering academic. Anti-Malthusian. Pro-humanity. Climate realist. Anti-'Woke'. Victorious Brexiteer. Neurodiverse. Each life matters.
# 100605                  Dad, husband, advocate for sustainable business, caterer, PADI MSDT, England & Wasps rugby fan. Trying to make a difference. All views my own
#
#                                                                                                                                           Clean
# 611                                                                            winters afternoon secluded chapel history england traditionalist
# 965                                                                                academic interests found espresso never enough books podcast
# 999                                                                             guatemala texas real madrid new england patriots options trader
# 1052                                                                       leeds west riding yorkshire england uk centre right lover rock music
# 1270                                                                                                  academic golfer husband father loves data
# ...                                                                                                                                         ...
# 97733           haydon manning retired academic four decades taught australian politics electoral behaviour flinders university south australia
# 97989         scientific research publishing scirp academic publisher open access journals also publishes academic books conference proceedings
# 99376                                                   father meteorologist skier hockey player alumnus native new englander naturalized texan
# 100594  scientist dad recovering academic anti malthusian pro humanity climate realist anti woke victorious brexiteer neurodiverse life matters
# 100605                         dad husband advocate sustainable business caterer padi msdt england wasps rugby fan trying make difference views
#
# [211 rows x 2 columns]

# %%
with_word3 =' '.join([i for i in ESN_group_with_word3['Clean']]).split()
no_word3 =' '.join([i for i in ESN_group_NO_word3['Clean']]).split()
quick_compare(with_word3, no_word3, num_words=40)
# Out:
# {'One_vs_two': {'greg': 36.1397424454928,
#   'kevin': 33.73042628245994,
#   'anthony': 32.12421550710471,
#   'stuart': 24.09316163032853,
#   'ryan': 24.09316163032853,
#   'todd': 24.09316163032853,
#   'craig': 24.09316163032853,
#   'brian': 21.902874209389573,
#   'jon': 21.41614367140314,
#   'dennis': 21.081516426537465,
#   'eric': 19.575693824641935,
#   'williams': 19.274529304262824,
#   'belgium': 19.274529304262824,
#   'jay': 18.739125712477747,
#   'douglas': 18.739125712477747,
#   'pennsylvania': 18.069871222746396,
#   'columbia': 17.84678639283595,
#   'matt': 17.20940116452038,
#   'daniel': 16.679881128688983,
#   'queensland': 16.679881128688983,
#   'denmark': 16.062107753552354,
#   'michael': 14.826561003279096,
#   'ray': 14.455896978197117,
#   'mike': 14.325663672087236,
#   'murray': 14.05434428435831,
#   'ct': 13.5524034170598,
#   'steve': 13.492170512983979,
#   'singapore': 13.141724525633743,
#   'sean': 13.141724525633743,
#   'rob': 12.973240877869207,
#   'david': 12.938920134806061,
#   'brisbane': 12.75520321605628,
#   'chris': 12.528444047770838,
#   'kingdom': 12.35546750273258,
#   'nederland': 12.046580815164267,
#   'wales': 12.046580815164265,
#   'dave': 12.046580815164265,
#   'harry': 12.046580815164265,
#   'scott': 12.046580815164265,
#   'ontario': 11.623893769018151},
#  'Two_vs_one': {'trump': 3.6333322658769656,
#   'writer': 3.5602541125113483,
#   'everything': 3.377514385557641,
#   'follower': 3.2097627750102316,
#   'see': 3.0951283901884374,
#   'may': 3.0575757468847464,
#   'big': 2.9646823660808788,
#   'president': 2.7854837875088787,
#   'account': 2.7549310886806566,
#   'patriot': 2.753201690633776,
#   'catholic': 2.7334371415265704,
#   'american': 2.688094940633569,
#   'artist': 2.6667317882897503,
#   'two': 2.645979011727184,
#   'get': 2.5669588240466434,
#   'let': 2.564120837508173,
#   'owner': 2.436968904918482,
#   'scientist': 2.4310395401863207,
#   'back': 2.426188241769097,
#   'endorsement': 2.4239243025077264,
#   'little': 2.4211572656327176,
#   'first': 2.407322081257673,
#   'dog': 2.3934868968826293,
#   'hard': 2.3554401398512583,
#   'political': 2.324310975007409,
#   'blue': 2.296640606257321,
#   'food': 2.2516762570384277,
#   'history': 2.2357657950071266,
#   'pro': 2.223511774560659,
#   'dogs': 2.211653045096335,
#   'old': 2.1928767234444897,
#   'christian': 2.1842297332100875,
#   'small': 2.183192094381959,
#   'beautiful': 2.1820062214355267,
#   'work': 2.177445171641556,
#   'economics': 2.1479123742255966,
#   'common': 2.142724180084955,
#   'mother': 2.136152467506809,
#   'founder': 2.1133244132879865,
#   'advocate': 2.0941438167680384}}

# %% [markdown]
# With the final compare for our second subgroup, let's choose one last word. Similar to the first text, I'm finding a strange occurance with a lot of names.

# %%
lexicon_list2 = lexicon_list2 + ['belgium', 'pennsylvania']
print(f'Our final lexicon for our subgroup 2 we determined')
lexicon_list2
# Out:
# Our final lexicon for our subgroup 2 we determined
# ['academic', 'netherlands', 'england', 'belgium', 'pennsylvania']

# %%
words ="|".join(word for word in lexicon_list2)  
ESN_group_with_word_final = ESN_descs[ESN_descs['Clean'].str.contains(words, case=False, na=False, regex=True)]
ESN_group_NO_word_final = ESN_descs[~ESN_descs['Clean'].str.contains(words, case=False, na=False)]
ESN_with_word=' '.join([i for i in ESN_group_with_word_final['Clean']]).split()
ESN_no_word =' '.join([i for i in ESN_group_NO_word_final['Clean']]).split()

# %% [markdown]
# ## The final group comparison
#
# Now that we have our lexicon of words, we can split of corpus into two groups--one with all those words present and one without.

# %%
group_compare(CF_with_word, ESN_with_word, num_words=30)
# Out:
# {'One': {'tokens': 31711,
#   'unique_tokens': 11004,
#   'avg_token_length': 6.163634070196462,
#   'lexical_diversity': 0.34700892434801806,
#   'top_10': [('de', 1103),
#    ('n', 829),
#    ('en', 612),
#    ('ambiental', 576),
#    ('la', 561),
#    ('el', 233),
#    ('educaci', 178),
#    ('e', 169),
#    ('ambientalista', 144),
#    ('del', 138),
#    ('climate', 131),
#    ('para', 119),
#    ('por', 116),
#    ('ambientales', 113),
#    ('tica', 103),
#    ('desarrollo', 102),
#    ('los', 98),
#    ('rica', 97),
#    ('gesti', 96),
#    ('pol', 93),
#    ('tico', 91),
#    ('con', 91),
#    ('social', 88),
#    ('un', 85),
#    ('es', 85),
#    ('investigaci', 84),
#    ('que', 81),
#    ('london', 81),
#    ('clim', 80),
#    ('las', 76)]},
#  'Two': {'tokens': 24634,
#   'unique_tokens': 11245,
#   'avg_token_length': 6.327230656815783,
#   'lexical_diversity': 0.45648290979946415,
#   'top_10': [('england', 162),
#    ('canada', 125),
#    ('usa', 123),
#    ('new', 95),
#    ('life', 81),
#    ('love', 74),
#    ('alberta', 73),
#    ('academic', 70),
#    ('conservative', 70),
#    ('father', 66),
#    ('husband', 62),
#    ('de', 60),
#    ('fan', 60),
#    ('ontario', 56),
#    ('united', 54),
#    ('truth', 52),
#    ('people', 50),
#    ('world', 50),
#    ('free', 48),
#    ('proud', 48),
#    ('london', 47),
#    ('one', 47),
#    ('south', 46),
#    ('lover', 45),
#    ('living', 45),
#    ('god', 45),
#    ('family', 43),
#    ('climate', 43),
#    ('van', 41),
#    ('science', 41)]},
#  'One_vs_two': {'la': 22.9368756317333,
#   'n': 21.466353421000072,
#   'el': 15.083414798229846,
#   'de': 14.28069229394637,
#   'en': 12.849158830553298,
#   'es': 8.253799943237363,
#   'que': 7.865385828261488,
#   'los': 7.612916653527168,
#   'un': 7.336711060655433,
#   'mi': 5.696740352979512,
#   'sustainable': 5.243590552174324,
#   'environment': 4.919912123027761,
#   'environmental': 4.725705065539823,
#   'e': 4.527033477994691,
#   'policy': 4.106092072602117,
#   'social': 3.5979412755660083,
#   'em': 3.3662556631242575,
#   'al': 3.1073129198070073,
#   'international': 2.996337458385328,
#   'san': 2.7620559287173396,
#   'msc': 2.7188988048311313,
#   'qu': 2.4599560615138807,
#   'climate': 2.3666162354344067,
#   'planet': 2.330484689855255,
#   'com': 2.330484689855255,
#   'innovation': 2.330484689855255,
#   'consultant': 2.2657490040259427,
#   'community': 2.20101331819663,
#   'l': 2.184829396739302,
#   'change': 2.0715419465380047},
#  'Two_vs_one': {'canada': 17.87897034811868,
#   'husband': 11.401674804857398,
#   'father': 10.620108386782496,
#   'retired': 7.938262834564695,
#   'family': 7.907613171110776,
#   'john': 7.355919228940256,
#   'great': 6.2218816811453,
#   'proud': 6.178972152309815,
#   'usa': 6.089852361651501,
#   'states': 6.068633363875712,
#   'mom': 6.068633363875712,
#   'toronto': 5.792786392790452,
#   'free': 5.617247411190742,
#   'pro': 5.3330414409816855,
#   'fan': 5.14914346025818,
#   'man': 4.988232727125112,
#   'anti': 4.965245479534673,
#   'sports': 4.863079934688281,
#   'living': 4.827321993992044,
#   'god': 4.827321993992044,
#   'david': 4.827321993992043,
#   'born': 4.6664112608589745,
#   'west': 4.597449518087661,
#   'always': 4.413551537364154,
#   'england': 4.34458979459284,
#   'life': 4.34458979459284,
#   'think': 4.229653556640647,
#   'state': 3.861857595193635,
#   'supporter': 3.677959614470128,
#   'love': 3.402112643384869}}

# %% [markdown]
# And now we have our final group comparison for the two sub groups from each group of followers' descriptions based on education lexicon. Remember, our first group had some good education words. Our second not so much.
#
# As we can see from the comparison above are more tokens for our first group where climate action is more popular. We also see a lot of climate actions words present. However, token length and lexical diversity is bigger for the second group. A big caveat is that the first group has a lot of Spanish, even though I used Spanish stopwords.
#
# Of extreme interest, I find some of the relatively high words in the second group interesting such as father, proud, usa, free. Especially when we consider that I started these groups based on education.
#
# Just for fun, I'll end it with the subgroups that weren't formed by education focused start words.

# %%
group_compare(CF_no_word, ESN_no_word, num_words=30)
# Out:
# {'One': {'tokens': 1111897,
#   'unique_tokens': 96049,
#   'avg_token_length': 6.434593312150316,
#   'lexical_diversity': 0.08638300130317826,
#   'top_10': [('de', 13031),
#    ('climate', 11859),
#    ('views', 6547),
#    ('energy', 6308),
#    ('change', 6294),
#    ('la', 6127),
#    ('en', 5820),
#    ('n', 5077),
#    ('world', 4605),
#    ('sustainable', 4496),
#    ('environmental', 4419),
#    ('sustainability', 4313),
#    ('development', 4031),
#    ('social', 3972),
#    ('global', 3940),
#    ('tweets', 3771),
#    ('director', 3694),
#    ('policy', 3207),
#    ('environment', 3193),
#    ('working', 3005),
#    ('science', 2948),
#    ('founder', 2945),
#    ('love', 2891),
#    ('people', 2811),
#    ('life', 2799),
#    ('business', 2752),
#    ('el', 2711),
#    ('international', 2663),
#    ('co', 2603),
#    ('research', 2542)]},
#  'Two': {'tokens': 565783,
#   'unique_tokens': 61699,
#   'avg_token_length': 6.095663885270501,
#   'lexical_diversity': 0.10905064309107909,
#   'top_10': [('love', 3296),
#    ('life', 2754),
#    ('conservative', 2737),
#    ('father', 2685),
#    ('husband', 2599),
#    ('fan', 2140),
#    ('proud', 1916),
#    ('de', 1793),
#    ('family', 1722),
#    ('free', 1714),
#    ('god', 1649),
#    ('world', 1647),
#    ('people', 1593),
#    ('lover', 1583),
#    ('freedom', 1511),
#    ('pro', 1499),
#    ('politics', 1476),
#    ('truth', 1462),
#    ('like', 1453),
#    ('retired', 1442),
#    ('dad', 1394),
#    ('time', 1337),
#    ('wife', 1323),
#    ('science', 1277),
#    ('christian', 1259),
#    ('good', 1244),
#    ('one', 1194),
#    ('business', 1149),
#    ('trump', 1136),
#    ('man', 1123)]},
#  'One_vs_two': {'costa': 35.110290791323294,
#   'rica': 32.174647748570514,
#   'programme': 28.438770157867342,
#   'adaptation': 22.59270885702543,
#   'biodiversity': 22.5279467923247,
#   'ngo': 20.071100210820887,
#   'periodista': 19.49511617308078,
#   'csr': 18.233605121097845,
#   'partnerships': 18.000384590479154,
#   'environnement': 17.979182724059275,
#   'ecological': 16.791878204545924,
#   'desarrollo': 16.724032232002305,
#   'sustainability': 16.62611815799049,
#   'partnership': 16.410244608988062,
#   'clim': 16.12646578152196,
#   'initiative': 15.632842840259086,
#   'loga': 15.54803537457956,
#   'blica': 15.434958753673527,
#   'cambio': 15.069634286130958,
#   'internacional': 15.0472674819957,
#   'resilience': 15.025887448631114,
#   'bangladesh': 15.010921425275903,
#   'circular': 14.714095295397565,
#   'oficial': 14.58688409687828,
#   'ppm': 14.126500711760857,
#   'feliz': 13.956885780401809,
#   'resilient': 13.891462878306175,
#   'nigeria': 13.5479926423041,
#   'organisations': 12.924657769559591,
#   'wellbeing': 12.890734783287781},
#  'Two_vs_one': {'conservative': 105.46765397098653,
#   'maga': 104.35402035762829,
#   'libertarian': 89.46994509797646,
#   'trudeau': 59.23782161813173,
#   'woke': 37.62022794705996,
#   'liberty': 36.946432819649935,
#   'saskatchewan': 36.02932278511962,
#   'patriot': 34.67549368652725,
#   'socialism': 33.900317347817094,
#   'grain': 31.880491676530085,
#   'jays': 29.150997526142238,
#   'trump': 27.90634819356538,
#   'calgary': 26.5306831417699,
#   'usmc': 26.5306831417699,
#   'constitution': 25.641647904215,
#   'alberta': 25.2457212802027,
#   'guns': 25.11134618356822,
#   'republican': 24.56544735349065,
#   'tyranny': 23.940145057219976,
#   'constitutional': 23.893129846974063,
#   'patriots': 23.189782301695175,
#   'speech': 22.845866038746305,
#   'wheat': 22.600211565211396,
#   'usaf': 21.617593671071774,
#   'denier': 20.634975776932144,
#   'fisherman': 20.213853822300877,
#   'cattle': 19.848881461620444,
#   'contrarian': 18.997279286699435,
#   'geen': 18.81011397352998,
#   'sucks': 17.687122094513267}}

# %% [markdown]
# I'll just leave that right there. That's probably more a comparison on the overall followers...
